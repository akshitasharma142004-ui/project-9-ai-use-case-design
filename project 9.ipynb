# %%
import pandas as pd

df = pd.read_csv("clean_customer_churn.csv")

# %%
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print("="*60)

print("BUSINESS PROBLEM")

print("="*60)

print("""
Telecom companies lose revenue because customers leave their services.

The goal is to identify customers who are likely to churn
before they leave the company.
""")
# Out:
# ...
# BUSINESS PROBLEM
# ...
#
# Telecom companies lose revenue because customers leave their services.
#
# The goal is to identify customers who are likely to churn
# before they leave the company.

# %%
print("="*60)

print("AI SOLUTION")

print("="*60)

print("""
Develop an AI-powered Customer Churn Prediction System
using Machine Learning.

The model will analyze customer information and
predict whether a customer is likely to churn.
""")
# Out:
# ...
# AI SOLUTION
# ...
#
# Develop an AI-powered Customer Churn Prediction System
# using Machine Learning.
#
# The model will analyze customer information and
# predict whether a customer is likely to churn.

# %%
print("="*60)

print("AI APPROACH")

print("="*60)

print("""
Artificial Intelligence Domain : Predictive AI

Machine Learning Type : Supervised Learning

Algorithm : Random Forest Classifier
""")
# Out:
# ...
# AI APPROACH
# ...
#
# Artificial Intelligence Domain : Predictive AI
#
# Machine Learning Type : Supervised Learning
#
# Algorithm : Random Forest Classifier

# %%
print("="*60)

print("INPUT FEATURES")

print("="*60)

for col in df.columns:

    if col!="Churn":

        print(col)
# Out:
# ...
# INPUT FEATURES
# ...
# customerID
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges

# %%
print("="*60)

print("EXPECTED OUTPUT")

print("="*60)

print("Customer Churn Prediction : Yes / No")
# Out:
# ...
# EXPECTED OUTPUT
# ...
# Customer Churn Prediction : Yes / No

# %%
print("="*60)

print("AI WORKFLOW")

print("="*60)

print("""
Data Collection

↓

Data Cleaning

↓

Feature Engineering

↓

Model Training

↓

Prediction

↓

Business Decision
""")
# Out:
# ...
# AI WORKFLOW
# ...
#
# Data Collection
#
# ↓
#
# Data Cleaning
#
# ↓
#
# Feature Engineering
#
# ↓
#
# Model Training
#
# ↓
#
# Prediction
#
# ↓
#
# Business Decision

# %%
print("="*60)

print("RISKS")

print("="*60)

print("""
1. Poor data quality.

2. Data imbalance.

3. Model bias.

4. Incorrect predictions.

5. Privacy concerns.
""")
# Out:
# ...
# RISKS
# ...
#
# 1. Poor data quality.
#
# 2. Data imbalance.
#
# 3. Model bias.
#
# 4. Incorrect predictions.
#
# 5. Privacy concerns.

# %%
print("="*60)

print("ETHICAL CONSIDERATIONS")

print("="*60)

print("""
1. Protect customer privacy.

2. Avoid biased predictions.

3. Ensure data transparency.

4. Use customer data responsibly.

5. Regularly monitor AI performance.
""")
# Out:
# ...
# ETHICAL CONSIDERATIONS
# ...
#
# 1. Protect customer privacy.
#
# 2. Avoid biased predictions.
#
# 3. Ensure data transparency.
#
# 4. Use customer data responsibly.
#
# 5. Regularly monitor AI performance.

# %%
print("="*60)

print("BUSINESS RECOMMENDATIONS")

print("="*60)

print("""
1. Deploy the AI model in CRM.

2. Target high-risk customers.

3. Improve customer support.

4. Personalize retention offers.

5. Retrain the AI model regularly.
""")
# Out:
# ...
# BUSINESS RECOMMENDATIONS
# ...
#
# 1. Deploy the AI model in CRM.
#
# 2. Target high-risk customers.
#
# 3. Improve customer support.
#
# 4. Personalize retention offers.
#
# 5. Retrain the AI model regularly.

# %%
print("="*60)

print("PROJECT CONCLUSION")

print("="*60)

print("""
An AI-based Customer Churn Prediction solution was designed.

The proposed AI system can help businesses reduce churn,
improve customer retention,
and increase long-term revenue.
""")
# Out:
# ...
# PROJECT CONCLUSION
# ...
#
# An AI-based Customer Churn Prediction solution was designed.
#
# The proposed AI system can help businesses reduce churn,
# improve customer retention,
# and increase long-term revenue.
